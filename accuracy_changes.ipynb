# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.metrics import mean_squared_error


x=10*np.random.normal(0,1,70)
y=10*(-x**2)+np.random.normal(-100,100,70)

plt.figure(figsize=(10,5))
plt.scatter(x,y,s=15)
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.show()

# %%
from sklearn.linear_model import LinearRegression


lm=LinearRegression()
lm.fit(x.reshape(-1,1),y.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_pred=lm.predict(x.reshape(-1,1))

plt.figure(figsize=(10,5))
plt.scatter(x,y,s=15)
plt.plot(x,y_pred,color='r')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.show()

# %%
print('Accuracy for Linear Regression=>',lm.score(x.reshape(-1,1),y.reshape(-1,1)))
# Out:
# Accuracy for Linear Regression=> 0.05963123906048695

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
Input=[('polynomial',PolynomialFeatures(degree=2)),('modal',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(x.reshape(-1,1),y.reshape(-1,1))
# Out:
# Pipeline(steps=[('polynomial', PolynomialFeatures()),
#                 ('modal', LinearRegression())])

# %%
poly_pred=pipe.predict(x.reshape(-1,1))
sorted_zip = sorted(zip(x,poly_pred))
x_poly, poly_pred = zip(*sorted_zip)

plt.figure(figsize=(10,6))
plt.scatter(x,y,s=15)
plt.plot(x,y_pred,color='r',label='Linear Regression')
plt.plot(x_poly,poly_pred,color='g',label='Polynomial Regression')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.legend()
plt.show()

# %%
print('Accuracy for Polynomial Regression=>',pipe.score(x.reshape(-1,1),y.reshape(-1,1)))
# Out:
# Accuracy for Polynomial Regression=> 0.9910837257347304
